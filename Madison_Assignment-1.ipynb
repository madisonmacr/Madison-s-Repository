# %% [markdown]
# # CISC 121 – Assignment-1
#
# ## 🔗 Problem
# Fizz Buzz – https://leetcode.com/problems/fizz-buzz/
#
# Palindrome Number – https://leetcode.com/problems/palindrome-number/
#
# Reverse Integer – https://leetcode.com/problems/reverse-integer/
#
# Two Sum – https://leetcode.com/problems/two-sum/
#
# Valid Palindrome – https://leetcode.com/problems/valid-palindrome/

# %% [markdown]
# 1. Your Name: Madison MacRury
# 2. Section: CISC121 001
# 3. ID: 24JSB2
# 4. Github Link of this notebook:

# %% [markdown]
# # **The most important part of writing code is not the code itself, but the thinking that leads to it. Thank You**

# %% [markdown]
# #Problem 1: FizzBuzz

# %% [markdown]
# #1. Understanding and Breakdown
#
# Problem: Generate a list of strings (or numbers as strings) from 1 to n. For multiples of 3, get the code to print "Fizz"; for multiples of 5, print "Buzz"; and for multiples of both 3 and 5, print "FizzBuzz"
#
# Input: Integer n (positive)
# Output: List of strings (length = n), where each position i is: "FizzBuzz"; "Fizz"; "Buzz" or the number i as string (if not divisible by 3 or 5)
#
# Constraints:
#
# Plan:
# 1. Make an empty list (ans) to store results.
# 2. Loop through all numbers from 1 to n.
# 3. For each number i (from 1 to n), use if, elif, else statements:
#   - if i % 3 == 0 and i % 5 == 0 -> "FizzBuzz"
#   - elif i % 3 == 0 -> "Fizz"
#   - elif i % 5 == 0 -> "Buzz"
#   - else -> i as string
# 4. After loop, return the list (ans)

# %% [markdown]
# #2. Peer Review and Draft Code

# %% [markdown]
# I reviewed the following attached top solution on LeetCode: https://leetcode.com/problems/fizz-buzz/solutions/4345360/beats-100-3-approaches-full-explained-java-c-python-javascript/
#
# - I learned that using if/elif/else ensured the proper order: first check both, then individually.
# - Using this idea, I wrote a function that loops from 1 to n, applies the conditions, and returns the list of results.

# %%
class Solution(object):
  def fizzBuzz(self, n: int) -> List[str]:
    ans = []

    for i in range(1, n+1):
      if i % 3 == 0 and i % 5 == 0:
        print("FizzBuzz")
      elif i % 3 == 0:
        print("Fizz")
      elif i % 5 == 0:
        print("Buzz")
      else:
        print(i)
    return ans

# %% [markdown]
# #3. Final Correct Code

# %%
#Final working solution
#AI Disclaimer: Used ChatGPT with prompt "How to structure if/elif/else fir FizzBuzz logic" only to understand the structure of conditional checks

# %%
from typing import List

class Solution(object):
  def fizzBuzz(Self, n: int) -> List[str]:
    ans = []

    for i in range(1, n + 1):
      if i % 3 == 0 and i % 5 == 0:
        ans.append("FizzBuzz")
      elif i % 3 == 0:
        ans.append("Fizz")
      elif i % 5 == 0:
        ans.append("Buzz")
      else:
        ans.append(str(i))
    return ans

# %%
#Test
sol = Solution()
print(sol.fizzBuzz(15))
# Out:
# ['1', '2', 'Fizz', '4', 'Buzz', 'Fizz', '7', '8', 'Fizz', 'Buzz', '11', 'Fizz', '13', '14', 'FizzBuzz']

# %%
#Test
print(sol.fizzBuzz(3))
# Out:
# ['1', '2', 'Fizz']

# %% [markdown]
# #4. Review & Fixes

# %%
#Fix 1: Replaced "print()" with "ans.append()"

#Draft Version
print("FizzBuzz")

#Correct Version
ans.append("FizzBuzz")

#Comment: Changed print() statements to ans.append() so that results are stored in a list, allowing the function to return the result as a List[str]
# Out:
# FizzBuzz
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4075057656.py in <cell line: 0>()
#       5
#       6 #Correct Version
# ----> 7 ans.append("FizzBuzz")
#       8
#       9 #Comment: Changed print() statements to ans.append() so that results are stored in a list, allowing the function to return the result as a List[str]
#
# NameError: name 'ans' is not defined

# %%
#Fix 2: Converted integers to strongs before appending

#Draft Version
print(i)

#Correct Version
ans.append(str(i))

# %%
#Fix 3: Added missing import for List from the typing module

#Draft Version
def fizzBuzz(self, n: int) -> List[str]:
## No import for List: Causes a NameError: name 'List' is not defined

#Correct Version
from typing import List

def fizzBuzz(self, n: int) -> List[str]:

#Comment: Added 'from typing import List' so the type hint 'List[str]' is recognized by Python.
##Without this, the code would raise a NameError since List wasn't defined.

# %% [markdown]
# #5. Reflection on Your Contribution

# %% [markdown]
# 1. ChatGPT helped me to understand the importance and logic behind appending results to a list rather than simply using the print function.
# 2. I personally revised the code to replace `print` with `ans.append()` and ensured that all cases ("Fizz","Buzz","FizzBuzz", and numbers) were correctly handled in the if/elif/else statements.
# 3. I manually traced the loop for multiple values of n to verify that all outputs matched expectations.

# %% [markdown]
# #Problem 2: Palidrome Number

# %% [markdown]
# #1. Understanding and Breakdown
#
# Problem: Given an integer, determine whether it reads the same backward as forward (palindrome). Return `True` if it is a palindrome number; otherwise, return `False`.
#
# Input: Integer x (can be negative or positive)
# Output: Boolean (`True` or `False` statements)
#
# Constraints:
#   - Negative numbers cannot be palindromes (minus sign)
#   - Numbers that end in 0 (i.e. 20), cannot be palindromes
#   - Very large / very small numbers (outside range) can lead to overflow: [-2^31,2^31-1]
#
# Plan:
# 1. Check for negative numbers. If x < 0, return `False`.
# 2. Change the number into a string (original)
# 3. Reverse the string
# 4. If the original string == reverse string, return True
# 5. Else, return False

# %% [markdown]
# #2. Peer Review and Draft Code

# %% [markdown]
# I reviewed the following attached top solution on LeetCode: https://leetcode.com/problems/palindrome-number/solutions/6826784/beats-100-step-by-step-visualization-java-c-python-beginner-friendly/
#
# - I learned that I can reverse the integer using a loop with modulo and division rather than converting it to a string
# - Using this idea, I wrote a function that reverses the number and compares it to the original to determine if it is a palindrome

# %%
class Solution(object):
    def isPalindrome(self, x: int): -> bool:
        if x < 0:
          return False

        reverse = 0

        while x > 0:
          reverse = reverse * 10 + x % 10
          x = x // 10

          if reverse = x:
            print(True)
          else:
            print(False)
# Out:
#   File "/tmp/ipython-input-556174231.py", line 2
#     def isPalindrome(self, x: int): -> bool:
#                                     ^
# SyntaxError: invalid syntax

# %% [markdown]
# #3. Final Correct Code

# %%
#Final working solution
#AI Disclaimer: Used Chat GPT with prompt: "How to handle recursion base case for negative numbers in integer palindrome check" to understand negative number handling
##All logic, integer division fix, and verification were done manually

# %%
class Solution():
    def isPalindrome(self, x: int) -> bool:
        if x < 0:
          return False

        original = x
        reverse = 0

        while x > 0:
          reverse = reverse * 10 + x % 10
          x = x // 10

        return reverse == original

# %%
#Test
sol = Solution()
print(sol.isPalindrome(1345431))
# Out:
# True

# %%
#Test
sol = Solution()
print(sol.isPalindrome(-12321))
# Out:
# False

# %%
#Test
sol = Solution()
print(sol.isPalindrome(1))
# Out:
# True

# %%
#Test
sol = Solution()
print(sol.isPalindrome(88))
# Out:
# True

# %% [markdown]
# #4. Review & Fixes

# %%
#Fix 1: Redundancy

#Draft Version
class Solution(object):

#Final Version
class Solution:

#Comment: "(object)" is redundant in Python; all classes inherit from object implicitly

# %%
#Fix 2: Annotation placed incorrectly

#Draft Version
  def isPalindrome(self, x: int): -> bool:

#Final Version
  def isPalindrome(self, x: int) -> bool:

# %%
#Fix 3: Used = instead of ==

#Draft Version
if reverse = x:

#Final Version
return reverse == x

# %%
#Fix 4: Return boolean instead of printing

#Draft Version
if reverse = x:
  print(True)
else:
  print(False)

#Final Version
return reverse == x

# %%
#Fix 5: Store original x

#Draft Version
        reverse = 0

        while x > 0:
          reverse = reverse * 10 + x % 10
          x = x // 10

          if reverse = x:
            print(True)
          else:
            print(False)

#Final Version
        original = x
        reverse = 0

        while x > 0:
          reverse = reverse * 10 + x % 10
          x = x // 10

        return reverse == original

#Comment: Stored the original x before modifying it so we can correctly compare it to the reversed number
# Out:
#   File "/tmp/ipython-input-1207455797.py", line 4
#     reverse = 0
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# #5. Reflection on Your Contribution
#
# 1. ChatGPT explained that using / division would result in floats, which could break the standing code logic for integers.
# 2. I fixed the draft by replacing / with // for integer division.
# 3. I ensured the code correctly handled negative numbers by returning False immediately, and I verified the logic by testing positive, negative, and single-digit numbers.

# %% [markdown]
# #Problem 3: Reverse Integer

# %% [markdown]
# #1. Understanding & Breakdown
#
# Problem: Given a signed 32-bit integer (x), reverse its digits. If reversing causes overflow (outside range), return 0.
#
# Input: Integer x
# Output: The reversed digit integer, or 0 if overflow
#
# Constraints:
#   - 32-bit signed integer range [-2^31,2^31-1]
#
# Plan:
# 1. Check if integer is outside range: If x is outside 32-bit integer range, return 0
# 2. Check if integer is negative: If x is negative, make it positive and reverse
# 3. Initialize a variable to store the reversed number (reverse = 0)
# 4. Loop through the digits of x
# 5. For all values of x (x>0):
#     - take the last digit (x%10)
#     - add it to reverse in the correct position (reverse * 10 + last digit)
#     - remove the last digit from x
# 6. Else, return reversed number

# %% [markdown]
# #2. Peer Review & Draft Code

# %% [markdown]
# I reviewed the following top solution on LeetCode: https://leetcode.com/problems/reverse-integer/solutions/4055/golfing-in-python/
# - I learned that recursive calls can simplify handling negative integers by converting them to positive and applying the same logic
# - Using this idea, I wrote a function that handles negative inputs with recursion, extracts each digit, and builds the reversed number

# %%
class Solution:
  def reverse(self, x: int) -> int:
    if x < 0:
      return self.reverse(-x)

    reverse = 0

    while x > 0:
      reverse = reverse * 10 + x % 10
      x = x / 10

    return reverse

# %% [markdown]
# #3. Final Correct Code

# %%
#Final working solution
#AI Disclaimer: Used ChatGPT with prompt: "How to handle overflow in Python" to understand 32-bit constraints
##Correct return value, sign handling, and overflow logic were manually implemented

class Solution:
  def reverse(self, x: int) -> int:
    negative = x < 0
    x = abs(x)
    reverse = 0

    while x > 0:
      reverse = reverse * 10 + x % 10
      x = x // 10

    if reverse > 2**31:
      return 0

    return -reverse if negative else reverse

# %%
#Test
sol = Solution()
print(sol.reverse(312))
# Out:
# 213

# %%
#Test
sol = Solution()
print(sol.reverse(-430))
# Out:
# -34

# %%
#Test
sol = Solution()
print(sol.reverse(1534236469))
# Out:
# 0

# %% [markdown]
# #4. Review & Fixes

# %%
#Fix 1: Removed recursion and preserved the negative sign manually

#Draft Version
def reverse(self, x: int) -> int:
  if x < 0:
    return self.reverse(-x)

  reverse = 0

  while x > 0:
    reverse = reverse * 10 + x % 10
    x = x / 10

  return reverse

#Final Version
class Solution:
  def reverse(self, x: int) -> int:
    negative = x < 0
    x = abs(x)
    reverse = 0

    while x > 0:
      reverse = reverse * 10 + x % 10
      x = x // 10

    if reverse > 2**31:
      return 0

    return -reverse if negative else reverse

#Comment: Replaced recursion with boolean flag to track negativity.
##This ensures the negative sign is reapplied at the end and avoids redundancy.

# %%
#Fix 2: Replaced float division with integer division to avoid float result

#Draft Version
x = x / 10

#Correct Version
x = x // 10

#Comment: Using '/' results in a float, which can break the loop logic or cause type errors.
##'//' ensures an integer result, as needed for digital manipulation.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2858063713.py in <cell line: 0>()
#       2
#       3 #Draft Version
# ----> 4 x = x / 10
#       5
#       6 #Correct Version
#
# NameError: name 'x' is not defined

# %%
#Fix 3: Added 32-bit signed integer overflow handling

#Draft Version
N/A #no overflow check

#Correct Version
    if reverse > 2**31:
      return 0

#Ensures function returns 0 when overflow occurs

# %% [markdown]
# #5. Reflection on Your Contribution

# %% [markdown]
# 1. ChatGPT helped me understand the general structure for reversing digits and handling the sign of the number.
# 2. I identified that the draft returned the wrong variable and used float division instead of integer division. I corrected these errors, ensured the reversed integer is returned properly, and added 32-bit overflow handling.
# 3. I traced test inputs manually to confirm correctness and effective overflow handling.

# %% [markdown]
# #Problem 4: Two Sum

# %% [markdown]
# #1. Understand & Breakdown
#
# Problem: Given an array of integers and a target integer, find two distinct numbers in that array whose sum equals the target and return their indices (positions). Assume each input has exactly one solution, and the same element must not be used twice.
#
# Inputs: Array of integers (nums), integer (target)
# Output: List of two indices [i,j] such that n[i] + n[j] == target and i != j
#
# Constraints:
#   - Only one valid solution per input
#   - The same element cannot be used twice
#   - Array must have at least 2 elements and at most 10,000 elements
#   - Each number (including the target) must be within range: [-10^9,10^9]
#
# Plan:
# 1. Initialize a hash table (num_map) to keep track of numbers and indices
# 2. Loop through each number in the array along with its index
# 3. For the currect number, calculate its complement as `target - num`
# 4. Check if this complement already exists in the hash table:
#   - If it does, return the indices of the complement and th current number
#   - If it does not, add the current number and its index to the hash table
# 5. Repeat until the end of the array. (Since exactly one solution exists, a valid pair is guaranteed)

# %% [markdown]
# #2. Peer Review & Draft Code

# %% [markdown]
# I reviewed the following top solution on LeetCode: https://leetcode.com/problems/two-sum/solutions/6483290/hash-table-python-c-java-js-c-go-rust-swift-kotlin-php-dart/
# - I learned that using a dictionary is more efficient than a list for storing numbers and their indices, because it allows quick lookups for complements
# - Using this idea, I wrote a function that iterates through the inputted array, stores each number and its index in a dictionary, and returns the pair of indices when a matching complement is found

# %%
class Solution:
  def twoSum(self, nums: List[int], target: int) -> List[int]:
    num_map = []
    for i, num in enumerate(nums):
      complement = target - num
      if complement in num_map:
        return [i, num_map[complement]]
      num_map[num] = i
    return []

# %% [markdown]
# #3. Final Correct Code

# %%
#Final working code
#AI Disclaimer: Used ChatGPT with prompt: "How to efficiently find two indices that sum to target using a hash map" to understand complement logic

class Solution:
  def twoSum(self, nums: List[int], target: int) -> List[int]:
    num_map = {}

    for i, num in enumerate(nums):
      complement = target - num

      if complement in num_map:
        return [num_map[complement], i]

      num_map[num] = i

    return []

# %%
#Test
sol = Solution()
print(sol.twoSum([5,2,13,15], 17))

# %%
#Test
sol = Solution()
print(sol.twoSum([3,2,4], 6))

# %%
#Test
sol = Solution()
print(sol.twoSum([13,3,9,10,1,5,23], 6))

# %% [markdown]
# #4. Review & Fixes

# %%
#Fix 1: Replaced list with dictionary to store numbers and indices

#Draft Version
num_map = []

#Correct Version
num_map = {}

#Comment: Lists cannot be used to map numbers to indices.
##A dictionary allows efficient key-value storage and lookup.

# %%
#Fix 2: Fixed Syntax Error

#Draft Version
return [i, num_map[complement]]

#Correct Version
return [num_map[complement], i]

#Comment: Indices were in the wrong order. Ensures the returned pair matches expected output.

# %% [markdown]
# #5. Reflection on Your Contribution
#
# 1. ChatGPT helped me understand the efficiency of using a dictionary for number to index mapping and the concept of a complement to find the target sum.
# 2. I manually tested examples(of varying array sizes), verifying that the returned pair always matched the expected result.

# %% [markdown]
# #Problem 5: Valid Palindrome

# %% [markdown]
# #1. Understand & Breakdown
#
# Problem: Given a string, determine if it is a palindrome considering only alphanumeric characters and ignoring cases. Return `True` if the cleaned version of the string reads the same both forwards and backwards.
#
# Input: String s (may include any characters)
# Output: Boolean (True and False statements)
#
# Constraints:
#   - Non-alphanumeric characters should be ignored (spaces, punctuation)
#   - Cases should be ignored ("A" == "a")
#   - Length of string must be within range [1,2*10^5]
#
# Plan:
# 1. Initialize empty list `filtered`
# 2. For each character c in s:
#     - If c is alphanumeric, append its lowercase version to `filtered`
# 3. Let `r_filtered` be the reverse of `filtered`
# 4. Return (True or False) whether `filtered == r_filtered`

# %% [markdown]
# #2. Peer Review & Draft Code

# %% [markdown]
# I reviewed the following top solution of LeetCode: https://leetcode.com/problems/valid-palindrome/solutions/39982/python-in-place-two-pointer-solution/
# - I learned that the isalnum() method correctly identifies alphanumeric characters, which allows ignoring spaces, punctuation, and other non-alphanumeric characters
# - Using this idea, I wrote a function that loops through the string, filters and lowercases only alphanumeric characters, then compares the filtered string to its reverse to determine if it is a palindrome

# %%
class Solution():
  def isPalindrome(self, s: str) -> bool:
    filtered = []

    for c in s:
      if c.isalnum:
        filtered.append(c.lower())

    r_filtered = filtered[::-1]

    if filtered == r_filtered
      return True
    else:
      return False

# %% [markdown]
# #3. Final Correct Code

# %%
#Final working solution
#AI Disclaimer: Used ChatGPT with prompt: "Why is isalnum failing without parentheses and how to correctly reverse a list in Python" only for concept understanding
##Filtering logic, slicing, and return type fixes were done manually

class Solution():
  def isPalindrome(self, s: str) -> bool:
    filtered = []

    for c in s:
      if c.isalnum():
        filtered.append(c.lower())

    r_filtered = filtered[::-1]

    return filtered == r_filtered

# %%
#Test
sol = Solution()
print(sol.isPalindrome("A man, a plan, a Canal: Panama"))

# %%
#Test
sol = Solution()
print(sol.isPalindrome("Goodmorning/ Kingston"))

# %%
#Test
sol = Solution()
print(sol.isPalindrome("NurSes Run"))

# %% [markdown]
# #4. Review & Fixes

# %%
#Fix 1: Corrected isalnum usage to properly check alphanumeric characters

#Draft Version
if c.isalnum:

#Correct Version
if c.isalnum():

#Comment: 'isalnum' must be called with parentheses.
##Without (), it evaluates as a function object, not a boolean.

# %%
#Fix 2: Return boolean value instead of string

#Draft Version
    if filtered == r_filtered
      return True
    else:
      return False

#Correct Version
return filtered == r_filtered

#Comment: The function must return a boolean value (True/False), not "True"/"False" as strings

# %% [markdown]
# #5. Reflection on Your Contribution
#
# 1. ChatGPT clarified why isalnum requred parentheses, and logic for other errors in my draft code.
# 2. I fixed all bugs myself, implemented [::-1] for reversing, and ensured the function returned a boolean.
# 3. I tested a variety of strings to confirm all cases and non-alphanumeric characters were ignored and code worked correctly.
